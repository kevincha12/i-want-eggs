# %% [markdown]
# ## Basic Wal-Mart Location Dataset Cleaning
# Please have your personal Kaggle API key setup and available in the correct location before running this notebook.
#
# The Kaggle dataset processed can be found here:
# https://www.kaggle.com/datasets/timmofeyy/-walmart-stores-location

# %%
import kaggle
import pandas as pd

# %%
kaggle.api.dataset_download_files('timmofeyy/-walmart-stores-location', path='./data', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/timmofeyy/-walmart-stores-location

# %%
walmart_store_location = pd.read_csv('./data/walmart_store_locaction.csv')
walmart_store_location.head()
# Out:
#                         name  \
# 0         Conway Supercenter
# 1       Sikeston Supercenter
# 2      Tahlequah Supercenter
# 3  Mountain Home Supercenter
# 4      Claremore Supercenter
#
#                                                  url          street_address  \
# 0  https://www.walmart.com/store/5/conway-ar/details       1155 Hwy 65 North
# 1  https://www.walmart.com/store/9/sikeston-mo/de...          1303 S Main St
# 2  https://www.walmart.com/store/10/tahlequah-ok/...     2020 S Muskogee Ave
# 3  https://www.walmart.com/store/11/mountain-home...          65 Wal Mart Dr
# 4  https://www.walmart.com/store/12/claremore-ok/...  1500 S Lynn Riggs Blvd
#
#             city state  zip_code country phone_number_1  phone_number_2  \
# 0         Conway    AR     72032      US   501-329-0023             NaN
# 1       Sikeston    MO     63801      US   573-472-3020             NaN
# 2      Tahlequah    OK     74464      US   918-456-8804             NaN
# ...

# %%
virginia_only = walmart_store_location[walmart_store_location['state'] == 'VA']
virginia_only.head()
# Out:
#                             name  \
# 150         Abingdon Supercenter
# 616          Big Stone Gap Store
# 976            Galax Supercenter
# 1191    Martinsville Supercenter
# 1232  Christiansburg Supercenter
#
#                                                     url  \
# 150   https://www.walmart.com/store/154/abingdon-va/...
# 616   https://www.walmart.com/store/650/big-stone-ga...
# 976   https://www.walmart.com/store/1023/galax-va/de...
# 1191  https://www.walmart.com/store/1243/martinsvill...
# 1232  https://www.walmart.com/store/1292/christiansb...
#
#                     street_address            city state  zip_code country  \
# 150   16032 Fifteen Mile Boulevard        Abingdon    VA     24211      US
# 616                 1941 Neeley Rd   Big Stone Gap    VA     24219      US
# 976               1140 E Stuart Dr           Galax    VA     24333      US
# 1191         976 Commonwealth Blvd    Martinsville    VA     24112      US
# ...
